# %%
from helper_chat import chat_thinking_response, add_user_message

# %%
# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"

# %%
messages = []

add_user_message(messages, "Write a one paragraph about AI Agents.")
#add_user_message(messages, thinking_test_str)

response = chat_thinking_response(messages, thinking=True)

print(response.content[0])
print(response.content[1].text)
response
